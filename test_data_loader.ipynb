# %%
import numpy as np
import matplotlib.pyplot as plt
from ai.DataLoader import DataLoader
from env import *

# %%
dloader = DataLoader(TRASH_TRAIN_DATA_PATH, TRASH_CAT)
# Out:
# Number of data batch: 793
# Number of batch: 133

# %%
x, y = next(dloader.next_batch())
x = x.reshape(-1, 6, 128, 128)
y = np.repeat(y, 8, axis=0)

# %%
plt.imshow((x[27, :3].transpose(1, 2, 0) + 0.5))
plt.show()
plt.imshow((x[27, 3:].transpose(1, 2, 0) + 0.5))
plt.show()
print(y[0])
# Out:
# 0.0

# %%
for i in range(100):
    print(dloader.data_list1[0][i])
    print(dloader.data_list2[0][i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-aba909ed21dc> in <module>
#       1 for i in range(100):
# ----> 2     print(dloader.data_list1[0][i])
#       3     print(dloader.data_list2[0][i])
#
# NameError: name 'dloader' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
from ai2.DataLoader import DataLoader
from env import *

# %%
dloader = DataLoader(TRASH_TRAIN_DATA_PATH, "trash")
# Out:
# Number of total data: 3383
# Number of batch: 106

# %%
x, y = next(dloader.next_batch())
# Out:
# 0.99609375 0.0

# %%
print(x.shape, y.shape)
# Out:
# (32, 8, 6, 128, 128) (32,)

# %%
print(x.max(), x.min())
# Out:
# 0.8869140625 -0.8869140625

# %%
np.sum((x[0, 0] > 0.01) | (x[0, 0] < -0.01))
# Out:
# 13518

# %%
np.sum((x[0, 0] < 0.01) & (x[0, 0] > -0.01))
# Out:
# 84786

# %%
plt.imshow((x[3, 4, :3]/255).transpose(1, 2, 0))
plt.show()
plt.imshow(x[3, 4, ..., 3:]/255)
plt.show()
print(y[3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-27d4054a99a1> in <module>
#       1 plt.imshow((x[3, 4, :3]/255).transpose(1, 2, 0))
#       2 plt.show()
# ----> 3 plt.imshow(x[3, 4, ..., 3:]/255)
#       4 plt.show()
#       5 print(y[3])
#
# ~/miniconda3/envs/torch/lib/python3.7/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2681         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2682         resample=resample, url=url, **({"data": data} if data is not
# -> 2683         None else {}), **kwargs)
#    2684     sci(__ret)
#    2685     return __ret
#
# ~/miniconda3/envs/torch/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...
