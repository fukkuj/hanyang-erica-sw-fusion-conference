# %% [markdown]
# # Artificial Intelligence

# %% [markdown]
# ## Import Libraries

# %%
from DataLoader import DataLoader
from env import *
from TrashDetector import TrashDetector

import torch
import torch.nn as nn
import torch.optim as optim

# %%
train_dloader = DataLoader(TRAIN_DATA_PATH)
valid_dloader = DataLoader(VALID_DATA_PATH)
# Out:
# Number of data batch: 580
# Number of batch: 73

# %%
model = TrashClassifier()
model = model.cuda()

# %%
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.parameters(), lr=ETA)

# %%
for e in range(EPOCHS):
    
    # loss and accuracy on train dataset.
    train_loss = 0.0
    train_acc = 0.0
    
    # loss and accuracy on valid dataset.
    val_loss = 0.0
    val_acc = 0.0
    
    # train step
    for x_batch, y_batch in train_dloader.next_batch():
        x_batch = torch.tensor(x_batch).float().cuda()
        y_batch = torch.tensor(y_batch).long().cuda()
        
        # forward propagation
        logps = model(x_batch)
        loss = criterion(logps, y_batch)
        train_loss += loss.item()
        
        # compute train accuracy
        with torch.no_grad():
            ps = torch.exp(logps)
            val_k, ind_k = ps.topk(1, dim=1)
            equal = ind_k == y_batch.view(*ind_k.shape)
            train_acc += torch.mean(equal.type(torch.FloatTensor)).item()
            
        # backward propagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
    # validation step
    model.eval()
    with torch.no_grad():
        for x_batch, y_batch in valid_dloader.next_batch():
            x_batch = torch.tensor(x_batch).float().cuda()
            y_batch = torch.tensor(y_batch).long().cuda()
            
            # compute validation loss
            logps = model(x_batch)
            loss = criterion(logps, y_batch)
            val_loss += loss.item()
            
            # compute validation accuracy
            ps = torch.exp(logps)
            value_k, index_k = ps.topk(1, dim=1)
            equal = index_k == y_batch.view(*index_k.size())
            val_acc += torch.mean(equal.type(torch.FloatTensor)).item()
        
    train_loss /= len(dloader)
    train_acc /= len(dloader)
    val_loss /= len(dloader)
    val_acc /= len(dloader)
    
    print(f"Epochs {e+1}/{EPOCHS}")
    print(f"Train loss: {train_loss:.8f}")
    print(f"Train acc: {train_acc:.8f}")
    print(f"Valid loss: {valid_loss:.8f}")
    print(f"Valid acc: {valid_acc:.8f}")
    
    model.train()
# Out:
# Epochs 1/50
# Train loss: 1.20096902
# Train acc: 0.47602740
# Epochs 2/50
# Train loss: 1.03572024
# Train acc: 0.57063359
# Epochs 3/50
# Train loss: 0.93081988
# Train acc: 0.61986303
# Epochs 4/50
# Train loss: 0.85717470
# Train acc: 0.65924656
# Epochs 5/50
# Train loss: 0.80485566
# Train acc: 0.68493152
# Epochs 6/50
# Train loss: 0.74177477
# Train acc: 0.71489727
# Epochs 7/50
# Train loss: 0.66228257
# Train acc: 0.74785960
# Epochs 8/50
# Train loss: 0.61709285
# Train acc: 0.76198632
# Epochs 9/50
# Train loss: 0.57543158
# Train acc: 0.78938359
# Epochs 10/50
# Train loss: 0.54687237
# Train acc: 0.78981167
# Epochs 11/50
# Train loss: 0.46679997
# Train acc: 0.83133560
